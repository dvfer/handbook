# %%
import requests
from bs4 import BeautifulSoup
from dotenv import load_dotenv
import json
import os
import pandas as pd

# %%
load_dotenv()
client_id = os.getenv("CLIENT_ID")

# %%
headers = {
    'X-MAL-CLIENT-ID': client_id
}
url = 'https://api.myanimelist.net/v2/users/Bonerva/animelist?fields=list_status&offset=10'

response = requests.get(url, headers=headers)

# 5. Check if it worked
user = "Bonerva"
url = f'https://api.myanimelist.net/v2/users/{user}/animelist?fields=list_status'
pages = []
while True:
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            data = response.json()
            url  = data.get("paging").get("next")
            # Pretty print the JSON result
            # print(json.dumps(data, indent=4))
            pages += data["data"]
            print(url)
        else:
            print(f"Error: {response.status_code}")
            print(response.text)
            break
    except:
        break
# Out:
# https://api.myanimelist.net/v2/users/Bonerva/animelist?offset=10&fields=list_status
# https://api.myanimelist.net/v2/users/Bonerva/animelist?offset=20&fields=list_status
# https://api.myanimelist.net/v2/users/Bonerva/animelist?offset=30&fields=list_status
# https://api.myanimelist.net/v2/users/Bonerva/animelist?offset=40&fields=list_status
# https://api.myanimelist.net/v2/users/Bonerva/animelist?offset=50&fields=list_status
# https://api.myanimelist.net/v2/users/Bonerva/animelist?offset=60&fields=list_status
# https://api.myanimelist.net/v2/users/Bonerva/animelist?offset=70&fields=list_status
# https://api.myanimelist.net/v2/users/Bonerva/animelist?offset=80&fields=list_status
# https://api.myanimelist.net/v2/users/Bonerva/animelist?offset=90&fields=list_status
# https://api.myanimelist.net/v2/users/Bonerva/animelist?offset=100&fields=list_status
# https://api.myanimelist.net/v2/users/Bonerva/animelist?offset=110&fields=list_status
# ...

# %%
anime_df = pd.DataFrame([
    {
        "id": page["node"]["id"],
        "name":page["node"]["title"],
        "status": page["list_status"]["status"],
        "score": page["list_status"]["score"]
    } for page in pages])

# %%
try:
    url = lambda x: 
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        data = response.json()
        url  = data.get("paging").get("next")
        # Pretty print the JSON result
        # print(json.dumps(data, indent=4))
        pages += data["data"]
        print(url)
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
except:
    print("a")
